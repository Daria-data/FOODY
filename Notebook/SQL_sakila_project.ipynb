# %% [markdown]
# # Sakila Database Project
#
# <div class ="alert alert-info">
#
# **!!REMEMBER!!**
#
# **SELECT * | col 1,col 2,.. col n**
#
# **FROM Table_name**
#
# **WHERE conditions**
#
# **GROUP BY col 1, col 2,...**
#
# **HAVING conditions**
#
# **ORDER BY col 1, col 2,...**
#
# **LIMIT n;**
#
# </div>

# %%
#Importer les dépendances
import mysql.connector as mysql
import pandas as pd

# %%
# Se Connecter à la BDD Sakila
#TBD
conn = mysql.connect(host='Localhost',user='root',passwd='Maxime29012018', database='sakila')
if conn:
    print("Connection Successful!")
else:
    print("Connection Failed!")
cur = conn.cursor()
# Out:
# Connection Successful!

# %%
# définir la fct sql_to_pandas

def sql_to_df(sql_query):

    # Use pandas to pass sql query using connection form SQLite3
    df = pd.read_sql(sql_query, conn)

    # Show the resulting DataFrame
    return df

# %% [markdown]
# <div class="alert alert-success">
#
# **1-**
# * Afficher les 5 premiers Records de la table Actor
# </div>

# %%
query = ''' SELECT * FROM actor '''

# Grab from first two columns
sql_to_df(query).head()
# Out:
#    actor_id first_name     last_name         last_update
# 0         1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2         3         ED         CHASE 2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33

# %% [markdown]
# <div class="alert alert-success">
#
# **2-**
# * Récupérer dans une colonne Actor_Name le full_name des acteurs sous le format: first_name + " " + last_name
#
# </div>

# %%
query ='''select concat (first_name," ", last_name) as Actor_Name from sakila.actor'''#TBD


sql_to_df(query).head()
# Out:
#             Actor_Name
# 0     PENELOPE GUINESS
# 1        NICK WAHLBERG
# 2             ED CHASE
# 3       JENNIFER DAVIS
# 4  JOHNNY LOLLOBRIGIDA

# %% [markdown]
# <div class="alert alert-success">
#
# **3-**
# * Récupérer dans une colonne Actor_Name le full_name des acteurs sous le format: first_name en minuscule + "." + last_name en majuscule
#
# </div>

# %% [markdown]
# **SQL Syntaxes**
#
# SELECT
#
#     CONCAT(lower(first_name), '.', UPPER(last_name)) AS 'Actor Name'
#
# FROM
#
# actor;

# %%
query ='''select concat (LOWER(first_name),".", last_name) as Actor_Name from sakila.actor'''#TBD


sql_to_df(query).head()
# Out:
#             Actor_Name
# 0     penelope.GUINESS
# 1        nick.WAHLBERG
# 2             ed.CHASE
# 3       jennifer.DAVIS
# 4  johnny.LOLLOBRIGIDA

# %% [markdown]
# <div class="alert alert-success">
#
# **4-**
# * Récupérer dans une colonne Actor_Name le full_name des acteurs sous le format: last_name en majuscule + "." + premiere lettre du first_name en majuscule
#
# </div>

# %%
query ='''SELECT CONCAT (last_name, ".",LEFT(first_name,1)) 
AS Actor_Name FROM sakila.actor'''#TBD


sql_to_df(query).head()
# Out:
#        Actor_Name
# 0       GUINESS.P
# 1      WAHLBERG.N
# 2         CHASE.E
# 3         DAVIS.J
# 4  LOLLOBRIGIDA.J

# %% [markdown]
# <div class="alert alert-success">
#
# **5-**
# * Trouver le ou les acteurs appelé(s) "JENNIFER"
#
#
# </div>

# %%
query ='''SELECT * FROM sakila.actor
WHERE first_name = 'JENNIFER' '''


sql_to_df(query).head()
# Out:
#    actor_id first_name last_name         last_update
# 0         4   JENNIFER     DAVIS 2006-02-15 04:34:33

# %% [markdown]
# <div class="alert alert-success">
#
# **6-**
# * Trouver les acteurs ayant des prénoms de 3 charactères.
#
# </div>

# %%
query = '''SELECT * FROM sakila.actor
WHERE LENGTH(first_name)=3 '''


sql_to_df(query).head()
# Out:
#    actor_id first_name last_name         last_update
# 0         9        JOE     SWANK 2006-02-15 04:34:33
# 1        13        UMA      WOOD 2006-02-15 04:34:33
# 2        18        DAN      TORN 2006-02-15 04:34:33
# 3        19        BOB   FAWCETT 2006-02-15 04:34:33
# 4        26        RIP  CRAWFORD 2006-02-15 04:34:33

# %% [markdown]
# <div class="alert alert-success">
#
# **7-**
# * Afficher les acteurs (actor_id, first_name, last_name, nbre char first_name, nbre char last_name )par ordre décroissant de longueur de prénoms
#
# </div>

# %%
query ='''SELECT actor_id, first_name, last_name, length(first_name) as 'nbre char first_name', length(last_name) as 'nbre char symbol last_name'
FROM sakila.actor
ORDER BY LENGTH(first_name) desc'''


sql_to_df(query).head()
# Out:
#    actor_id   first_name last_name  nbre char first_name  \
# 0        91  CHRISTOPHER     BERRY                    11
# 1       163  CHRISTOPHER      WEST                    11
# 2       173  MUCHO ALLAN  DREYFUSS                    11
# 3        10    CHRISTIAN     GABLE                     9
# 4        58    CHRISTIAN    AKROYD                     9
#
#    nbre char symbol last_name
# 0                           5
# 1                           4
# 2                           8
# 3                           5
# 4                           6

# %% [markdown]
# <div class="alert alert-success">
#
# **8-**
# * Afficher les acteurs (actor_id, first_name, last_name, nbre char first_name, nbre char last_name )par ordre décroissant de longueur de prénoms et croissant de longuer de noms
#
# </div>

# %%
query ='''SELECT actor_id, first_name, last_name, length(first_name) as 'nbre char first_name', length(last_name) as 'nbre char symbol last_name'
FROM sakila.actor
ORDER BY LENGTH(first_name) desc, LENGTH(last_name) ASC'''

sql_to_df(query).head()
# Out:
#    actor_id   first_name last_name  nbre char first_name  \
# 0       163  CHRISTOPHER      WEST                    11
# 1        91  CHRISTOPHER     BERRY                    11
# 2       109    SYLVESTER      DERN                     9
# 3        10    CHRISTIAN     GABLE                     9
# 4        58    CHRISTIAN    AKROYD                     9
#
#    nbre char symbol last_name
# 0                           4
# 1                           5
# 2                           4
# 3                           5
# 4                           6

# %% [markdown]
# <div class="alert alert-success">
#
# **9-**
# * Trouver les acteurs ayant dans leurs last_names la chaine: "SON
#
#
# </div>

# %%
query ='''SELECT * FROM sakila.actor
WHERE last_name LIKE ('%SON%')'''


sql_to_df(query).head()
# Out:
#    actor_id first_name  last_name         last_update
# 0         6      BETTE  NICHOLSON 2006-02-15 04:34:33
# 1         8    MATTHEW  JOHANSSON 2006-02-15 04:34:33
# 2        61  CHRISTIAN     NEESON 2006-02-15 04:34:33
# 3        62      JAYNE     NEESON 2006-02-15 04:34:33
# 4        64        RAY  JOHANSSON 2006-02-15 04:34:33

# %% [markdown]
# <div class="alert alert-success">
#
# **10-**
# * Trouver les acteurs ayant des last_names commençant par la chaine: "JOH"
#
#
# </div>

# %%
query ='''SELECT * FROM sakila.actor
WHERE last_name LIKE ('JOH%')'''


sql_to_df(query).head()
# Out:
#    actor_id first_name  last_name         last_update
# 0         8    MATTHEW  JOHANSSON 2006-02-15 04:34:33
# 1        64        RAY  JOHANSSON 2006-02-15 04:34:33
# 2       146     ALBERT  JOHANSSON 2006-02-15 04:34:33

# %% [markdown]
# <div class="alert alert-success">
#
# **11-**
# *  Afficher par ordre alphabétique croissant les last_names et les first_names des acteurs ayant dans leurs last_names la chaine "LI"
#
#
# </div>

# %%
query ='''SELECT * FROM sakila.actor
WHERE last_name LIKE ('%LI%')
ORDER BY last_name, first_name'''


sql_to_df(query).head()
# Out:
#    actor_id first_name last_name         last_update
# 0        86       GREG   CHAPLIN 2006-02-15 04:34:33
# 1        82      WOODY     JOLIE 2006-02-15 04:34:33
# 2        34     AUDREY   OLIVIER 2006-02-15 04:34:33
# 3        15       CUBA   OLIVIER 2006-02-15 04:34:33
# 4       172    GROUCHO  WILLIAMS 2006-02-15 04:34:33

# %% [markdown]
# <div class="alert alert-success">
#
# **12-**
# *  Trouver dans la table country les countries "China", "Afghanistan", "Bangladesh"
#
#
# </div>

# %%
query ='''SELECT * FROM sakila.country
WHERE country IN ("China", "Afghanistan", "Bangladesh")'''#TBD


sql_to_df(query).head()
# Out:
#    country_id      country         last_update
# 0           1  Afghanistan 2006-02-15 04:44:00
# 1          12   Bangladesh 2006-02-15 04:44:00
# 2          23        China 2006-02-15 04:44:00

# %% [markdown]
# <div class="alert alert-success">
#
# **13-**
# * Trouver le nombre des acteurs ayant le meme last_name
# * Afficher le resultat  par ordre décroissant
#
#
# </div>

# %%
query = '''SELECT last_name, count(last_name) FROM sakila.actor GROUP BY last_name order by count(last_name) desc '''

sql_to_df(query).head()
# Out:
#   last_name  count(last_name)
# 0    KILMER                 5
# 1     NOLTE                 4
# 2    TEMPLE                 4
# 3    AKROYD                 3
# 4     ALLEN                 3

# %% [markdown]
# <div class="alert alert-success">
#
# **14-**
# * Trouver le nombre des acteurs ayant le meme last_name
# * Afficher UNIQUEMENT les last_names communs à au moins 3 acteurs
# * Afficher par ordre alph. croissant
#
# </div>

# %%
query ='''SELECT last_name from sakila.actor 
GROUP BY last_name
HAVING COUNT(last_name) >=3 
ORDER BY last_name '''#TBD


sql_to_df(query).head()
# Out:
#    last_name
# 0     AKROYD
# 1      ALLEN
# 2      BERRY
# 3      DAVIS
# 4  DEGENERES

# %% [markdown]
# <div class="alert alert-success">
#
# **15-**
# * Trouver le nombre des acteurs ayant le meme first_name Afficher le resultat par ordre alph. croissant
#
# </div>

# %%
query ='''SELECT *, count(first_name) FROM sakila.actor GROUP BY first_name order by first_name asc'''#TBD


sql_to_df(query).head()
# Out:
#    actor_id first_name last_name         last_update  count(first_name)
# 0        71       ADAM     GRANT 2006-02-15 04:34:33                  2
# 1       165         AL   GARLAND 2006-02-15 04:34:33                  1
# 2       125     ALBERT     NOLTE 2006-02-15 04:34:33                  2
# 3        29       ALEC     WAYNE 2006-02-15 04:34:33                  1
# 4        65     ANGELA    HUDSON 2006-02-15 04:34:33                  2

# %% [markdown]
# <div class="alert alert-success">
#
# **16-**
# * Corriger le first_name de l'acteur HARPO WILLIAMS qui était accidentellement inséré à GROUCHO WILLIAMS
#
#
# </div>

# %%
query =''' UPDATE sakila.actor SET first_name = 'GROUCHO'
WHERE first_name = 'HARPO' AND last_name = 'WILLIAMS' '''

sql_to_df(query).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-c91d13a4aa3a> in <module>
#       2 WHERE first_name = 'HARPO' AND last_name = 'WILLIAMS' '''
#       3
# ----> 4 sql_to_df(query).head()
#
# <ipython-input-18-3bd755dd28cf> in sql_to_df(sql_query)
#       4
#       5     # Use pandas to pass sql query using connection form SQLite3
# ----> 6     df = pd.read_sql(sql_query, conn)
#       7
#       8     # Show the resulting DataFrame
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1726         args = _convert_params(sql, params)
#    1727         cursor = self.execute(*args)
# -> 1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#    1730         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# <div class="alert alert-success">
#
# **17-**
# * Trouver les first_names,last names et l'adresse de chacun des membre staff
#
# RQ: utiliser join avec les tables staff & address:
#
# </div>

# %%
query ='''SELECT s.first_name, s.last_name, a.address
FROM sakila.staff s
LEFT JOIN sakila.address a
ON s.address_id = a.address_id'''#TBD


sql_to_df(query).head()
# Out:
#   first_name last_name               address
# 0       Mike   Hillyer     23 Workhaven Lane
# 1        Jon  Stephens  1411 Lillydale Drive

# %% [markdown]
# <div class="alert alert-success">
#
# **18-**
# * Afficher pour chaque membre du staff ,le total de ses salaires depuis Aout 2005. RQ: Utiliser les tables staff & payment.
#
# </div>

# %%
query ='''SELECT staff.first_name, staff.last_name,SUM(payment.amount) 
    FROM staff INNER JOIN payment ON staff.staff_id=payment.staff_id
    WHERE payment.payment_date> 2005-07-31
    GROUP BY payment.staff_id; '''#TBD


sql_to_df(query).head()
# Out:
#   first_name last_name  SUM(payment.amount)
# 0       Mike   Hillyer             33489.47
# 1        Jon  Stephens             33927.04

# %% [markdown]
# <div class="alert alert-success">
#
# **19-**
# * Afficher pour chaque film ,le nombre de ses acteurs
#
# </div>

# %%
query ='''SELECT f.title, count(actor_id) as nbr_acteurs FROM sakila.film_actor 
left join sakila.film f
using(film_id)
group by film_id'''#TBD


sql_to_df(query).head()
# Out:
#               title  nbr_acteurs
# 0  ACADEMY DINOSAUR           10
# 1    ACE GOLDFINGER            4
# 2  ADAPTATION HOLES            5
# 3  AFFAIR PREJUDICE            5
# 4       AFRICAN EGG            5

# %% [markdown]
# <div class="alert alert-success">
#
# **20-**
# * Trouver le film intitulé "HUNCHBACK IMPOSSIBLE"
#
#
# </div>

# %%
query ='''SELECT * FROM sakila.film
WHERE title = "Hunchback Impossible" '''#TBD


sql_to_df(query).head()
# Out:
#    film_id                 title  \
# 0      439  HUNCHBACK IMPOSSIBLE
#
#                                          description  release_year  \
# 0  A Touching Yarn of a Frisbee And a Dentist who...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                4         4.99     151
#
#    replacement_cost rating            special_features         last_update
# 0             28.99  PG-13  {Trailers, Deleted Scenes} 2006-02-15 05:03:42

# %% [markdown]
# <div class="alert alert-success">
#
# **21-**
# * Combien de copies exist t il dans le systme d'inventaire pour le film Hunchback Impossible
#
# </div>

# %%
query ='''SELECT count(inventory_id) as 'copies exist t il dans le systme' FROM sakila.inventory
where film_id = '439' '''#TBD


sql_to_df(query).head()
# Out:
#    copies exist t il dans le systme
# 0                                 6

# %% [markdown]
# <div class="alert alert-success">
#
# **22-**
# * Afficher les titres des films en anglais commençant par 'K' ou 'Q'
#
# </div>

# %%
query ='''SELECT f.title FROM sakila.film f
LEFT JOIN sakila.language l
ON l.language_id=f.language_id
WHERE (l.name='English' AND (f.title LIKE ('K%') or f.title LIKE ('Q%')) )'''#TBD

sql_to_df(query).head()
# Out:
#               title
# 0     KANE EXORCIST
# 1       KARATE MOON
# 2  KENTUCKIAN GIANT
# 3     KICK SAVANNAH
# 4  KILL BROTHERHOOD

# %% [markdown]
# # Bonus

# %% [markdown]
# <div class="alert alert-success">
#
# * Afficher les first et last names des acteurs qui ont participé au film intitulé 'ACADEMY DINOSAUR'
#
# </div>

# %%
query ='''SELECT a.first_name, a.last_name FROM sakila.actor a
LEFT JOIN sakila.film_actor fa
ON fa.actor_id=a.actor_id
LEFT JOIN sakila.film f 
ON fa.film_id=f.film_id
WHERE f.title='ACADEMY DINOSAUR' '''#TBD


sql_to_df(query).head(20)
# Out:
#   first_name last_name
# 0   PENELOPE   GUINESS
# 1  CHRISTIAN     GABLE
# 2    LUCILLE     TRACY
# 3     SANDRA      PECK
# 4     JOHNNY      CAGE
# 5       MENA    TEMPLE
# 6     WARREN     NOLTE
# 7      OPRAH    KILMER
# 8       ROCK   DUKAKIS
# 9       MARY    KEITEL

# %% [markdown]
# <div class="alert alert-success">
#
# * Trouver la liste des film catégorisés comme family films.
#
# </div>

# %%
query ='''SELECT f.title FROM sakila.film f
LEFT JOIN sakila.film_category fc
ON fc.film_id=f.film_id
LEFT JOIN sakila.category c
ON c.category_id=fc.category_id
WHERE c.name = 'Family' '''#TBD

sql_to_df(query).head()
# Out:
#              title
# 0      AFRICAN EGG
# 1    APACHE DIVINE
# 2   ATLANTIS CAUSE
# 3  BAKED CLEOPATRA
# 4        BANG KWAI

# %% [markdown]
# <div class="alert alert-success">
#
# * Afficher le top 5 des films les plus loués par ordre decroissant
#
# </div>

# %%
query ='''SELECT film.title, COUNT(inventory.film_id) AS NbRental
FROM film
INNER JOIN inventory USING (film_id)
INNER JOIN rental USING (inventory_id)
GROUP BY inventory.film_id
ORDER BY NbRental DESC
LIMIT 5'''#TBD


sql_to_df(query).head()
# Out:
#                 title  NbRental
# 0  BUCKET BROTHERHOOD        34
# 1    ROCKETEER MOTHER        33
# 2      FORWARD TEMPLE        32
# 3      GRIT CLOCKWORK        32
# 4      JUGGLER HARDLY        32

# %% [markdown]
# <div class="alert alert-success">
#
# * Afficher le chiffre d'affaire par store. RQ: le chiffre d'affaire = somme (amount)
#
# </div>

# %%
query ='''SELECT store_id,ci.city, co.country, sum(p.amount) as chiffre_daffaire
FROM sakila.payment p
left join sakila.staff sta
using(staff_id)
left join sakila.store sto
using(store_id)
left join sakila.address a 
on a.address_id=sto.address_id
left join sakila.city ci 
using(city_id)
left join sakila.country co 
using(country_id)
group by sta.store_id'''#TBD


sql_to_df(query).head()
# Out:
#    store_id        city    country  chiffre_daffaire
# 0         1  Lethbridge     Canada          33489.47
# 1         2   Woodridge  Australia          33927.04

# %% [markdown]
# <div class="alert alert-success">
#
# * Lister par ordre décroissant le top 5 des catégories ayant le plus des revenues.
#
# RQ utiliser les tables : category, film_category, inventory, payment, et rental.
#
# </div>

# %%
query ='''SELECT category.name,SUM(payment.amount) FROM category
    INNER JOIN  film_category ON category.category_id=film_category.category_id
    INNER JOIN  inventory ON film_category.film_id=inventory.film_id
    INNER JOIN  rental ON rental.inventory_id=inventory.inventory_id
    INNER JOIN payment ON rental.rental_id=payment.rental_id
    GROUP BY film_category.category_id
    ORDER BY SUM(payment.amount) DESC LIMIT 5'''

sql_to_df(query).head()
# Out:
#         name  SUM(payment.amount)
# 0     Sports              5314.21
# 1     Sci-Fi              4756.98
# 2  Animation              4656.30
# 3      Drama              4587.39
# 4     Comedy              4383.58

# %% [markdown]
# ## Bon travail!
